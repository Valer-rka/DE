# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('data/features_train.csv')
df2 = pd.read_csv('data/labels_train.csv')

# %%
df2.head()
# Out:
#   city  year  weekofyear  total_cases
# 0   sj  1990          18            4
# 1   sj  1990          19            5
# 2   sj  1990          20            4
# 3   sj  1990          21            3
# 4   sj  1990          22            6

# %%
df1.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
# 3  0.235886                 15.36             298.987143  ...
# 4  0.247340                  7.52             299.518571  ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            32.00                             73.365714
# ...

# %%
df = df1.merge(df2, on = ['city','year','weekofyear'])
df.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
# 3  0.235886                 15.36             298.987143  ...
# 4  0.247340                  7.52             299.518571  ...
#
#    reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# 0                             73.365714                         12.42
# ...

# %%
df.drop("ndvi_ne",axis=1).dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1353 entries, 0 to 1455
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   city                                   1353 non-null   object
#  1   year                                   1353 non-null   int64
#  2   weekofyear                             1353 non-null   int64
#  3   week_start_date                        1353 non-null   object
#  4   ndvi_nw                                1353 non-null   float64
#  5   ndvi_se                                1353 non-null   float64
#  6   ndvi_sw                                1353 non-null   float64
#  7   precipitation_amt_mm                   1353 non-null   float64
#  8   reanalysis_air_temp_k                  1353 non-null   float64
#  9   reanalysis_avg_temp_k                  1353 non-null   float64
# ...

# %%
df.describe()
# Out:
#               year   weekofyear      ndvi_ne      ndvi_nw      ndvi_se  \
# count  1456.000000  1456.000000  1262.000000  1404.000000  1434.000000
# mean   2001.031593    26.503434     0.142294     0.130553     0.203783
# std       5.408314    15.019437     0.140531     0.119999     0.073860
# min    1990.000000     1.000000    -0.406250    -0.456100    -0.015533
# 25%    1997.000000    13.750000     0.044950     0.049217     0.155087
# 50%    2002.000000    26.500000     0.128817     0.121429     0.196050
# 75%    2005.000000    39.250000     0.248483     0.216600     0.248846
# max    2010.000000    53.000000     0.508357     0.454429     0.538314
#
#            ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# count  1434.000000           1443.000000            1446.000000
# mean      0.202305             45.760388             298.701852
# std       0.083903             43.715537               1.362420
# min      -0.063457              0.000000             294.635714
# ...

# %%
df.boxplot(column = ['ndvi_ne'])
# Out:
# <AxesSubplot:>

# %%
IQR=df['ndvi_ne'].quantile(0.75)-df['ndvi_ne'].quantile(0.25)
lower=df['ndvi_ne'].quantile(0.25)-1.5*IQR
upper=df['ndvi_ne'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -0.2603499875 0.5537833125

# %%
df=df[df['ndvi_ne']>=lower]
df.boxplot(column = ['ndvi_ne'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = ['ndvi_nw'])
# Out:
# <AxesSubplot:>

# %%
IQR=df['ndvi_nw'].quantile(0.75)-df['ndvi_nw'].quantile(0.25)
lower=df['ndvi_nw'].quantile(0.25)-1.5*IQR
upper=df['ndvi_nw'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -0.204 0.48560000000000003

# %%
df=df[df['ndvi_nw']>=lower]
df.boxplot(column = ['ndvi_nw'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = ['ndvi_se'])
# Out:
# <AxesSubplot:>

# %%
IQR=df['ndvi_se'].quantile(0.75)-df['ndvi_se'].quantile(0.25)
lower=df['ndvi_se'].quantile(0.25)-1.5*IQR
upper=df['ndvi_se'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# 0.011465625000000035 0.39984062499999995

# %%
df=df[df['ndvi_se']>=lower]
df=df[df['ndvi_se']<=upper]
df.boxplot(column = ['ndvi_se'])
# Out:
# <AxesSubplot:>

# %%
IQR=df['ndvi_se'].quantile(0.75)-df['ndvi_se'].quantile(0.25)
lower=df['ndvi_se'].quantile(0.25)-1.5*IQR
upper=df['ndvi_se'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# 0.014950000000000047 0.3929499999999999

# %%
df=df[df['ndvi_se']>=lower]
df=df[df['ndvi_se']<=upper]
df.boxplot(column = ['ndvi_se'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = ['ndvi_sw'])

# %%
IQR=df['ndvi_sw'].quantile(0.75)-df['ndvi_sw'].quantile(0.25)
lower=df['ndvi_sw'].quantile(0.25)-1.5*IQR
upper=df['ndvi_sw'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -0.018312462500000043 0.4188446375

# %%
df=df[df['ndvi_sw']<=upper]
df.boxplot(column = ['ndvi_sw'])

# %%
IQR=df['ndvi_sw'].quantile(0.75)-df['ndvi_sw'].quantile(0.25)
lower=df['ndvi_sw'].quantile(0.25)-1.5*IQR
upper=df['ndvi_sw'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -0.011982250000000028 0.40678935000000005

# %%
df=df[df['ndvi_sw']>=lower]
df=df[df['ndvi_sw']<=upper]
df.boxplot(column = ['ndvi_sw'])

# %%
df.boxplot(column = ['precipitation_amt_mm'])

# %%
IQR=df['precipitation_amt_mm'].quantile(0.75)-df['precipitation_amt_mm'].quantile(0.25)
lower=df['precipitation_amt_mm'].quantile(0.25)-1.5*IQR
upper=df['precipitation_amt_mm'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -75.1225 159.7575

# %%
df=df[df['precipitation_amt_mm']<=upper]
df.boxplot(column = ['precipitation_amt_mm'])

# %%
df.boxplot(column = ['reanalysis_avg_temp_k'])

# %%
IQR=df['reanalysis_avg_temp_k'].quantile(0.75)-df['reanalysis_avg_temp_k'].quantile(0.25)
lower=df['reanalysis_avg_temp_k'].quantile(0.25)-1.5*IQR
upper=df['reanalysis_avg_temp_k'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# 295.35089285724996 303.14374999924996

# %%
df=df[df['reanalysis_avg_temp_k']>=lower]
df.boxplot(column = ['reanalysis_avg_temp_k'])

# %%
df.boxplot(column = ['reanalysis_dew_point_temp_k'])

# %%
IQR=df['reanalysis_dew_point_temp_k'].quantile(0.75)-df['reanalysis_dew_point_temp_k'].quantile(0.25)
lower=df['reanalysis_dew_point_temp_k'].quantile(0.25)-1.5*IQR
upper=df['reanalysis_dew_point_temp_k'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# 290.7744642858751 299.9358928568749

# %%
df=df[df['reanalysis_dew_point_temp_k']>=lower]
df.boxplot(column = ['reanalysis_dew_point_temp_k'])

# %%
IQR=df['reanalysis_dew_point_temp_k'].quantile(0.75)-df['reanalysis_dew_point_temp_k'].quantile(0.25)
lower=df['reanalysis_dew_point_temp_k'].quantile(0.25)-1.5*IQR
upper=df['reanalysis_dew_point_temp_k'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# 290.824285714 299.915714286

# %%
df=df[df['reanalysis_dew_point_temp_k']>=lower]
df.boxplot(column = ['reanalysis_dew_point_temp_k'])

# %%
df.boxplot(column = ['reanalysis_max_air_temp_k'])

# %%
df.boxplot(column = ['reanalysis_min_air_temp_k'])

# %%
IQR=df['reanalysis_min_air_temp_k'].quantile(0.75)-df['reanalysis_min_air_temp_k'].quantile(0.25)
lower=df['reanalysis_min_air_temp_k'].quantile(0.25)-1.5*IQR
upper=df['reanalysis_min_air_temp_k'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# 287.1500000000001 304.3499999999999

# %%
df=df[df['reanalysis_min_air_temp_k']>=lower]
df.boxplot(column = ['reanalysis_min_air_temp_k'])

# %%
df.boxplot(column = ['reanalysis_precip_amt_kg_per_m2'])

# %%
IQR=df['reanalysis_precip_amt_kg_per_m2'].quantile(0.75)-df['reanalysis_precip_amt_kg_per_m2'].quantile(0.25)
lower=df['reanalysis_precip_amt_kg_per_m2'].quantile(0.25)-1.5*IQR
upper=df['reanalysis_precip_amt_kg_per_m2'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -47.15 114.85

# %%
df=df[df['reanalysis_precip_amt_kg_per_m2']<=upper]
df.boxplot(column = ['reanalysis_precip_amt_kg_per_m2'])

# %%
IQR=df['reanalysis_precip_amt_kg_per_m2'].quantile(0.75)-df['reanalysis_precip_amt_kg_per_m2'].quantile(0.25)
lower=df['reanalysis_precip_amt_kg_per_m2'].quantile(0.25)-1.5*IQR
upper=df['reanalysis_precip_amt_kg_per_m2'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -40.075 100.925

# %%
df=df[df['reanalysis_precip_amt_kg_per_m2']<=upper]
df.boxplot(column = ['reanalysis_precip_amt_kg_per_m2'])

# %%
IQR=df['reanalysis_precip_amt_kg_per_m2'].quantile(0.75)-df['reanalysis_precip_amt_kg_per_m2'].quantile(0.25)
lower=df['reanalysis_precip_amt_kg_per_m2'].quantile(0.25)-1.5*IQR
upper=df['reanalysis_precip_amt_kg_per_m2'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -38.19500000000001 97.605

# %%
df=df[df['reanalysis_precip_amt_kg_per_m2']<=upper]
df.boxplot(column = ['reanalysis_precip_amt_kg_per_m2'])

# %%
df.boxplot(column = ['reanalysis_relative_humidity_percent'])

# %%
IQR=df['reanalysis_relative_humidity_percent'].quantile(0.75)-df['reanalysis_relative_humidity_percent'].quantile(0.25)
lower=df['reanalysis_relative_humidity_percent'].quantile(0.25)-1.5*IQR
upper=df['reanalysis_relative_humidity_percent'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# 64.07410714296248 99.19839285706252

# %%
df=df[df['reanalysis_relative_humidity_percent']>=lower]
df.boxplot(column = ['reanalysis_relative_humidity_percent'])

# %%
df.boxplot(column = ['reanalysis_sat_precip_amt_mm'])

# %%
IQR=df['reanalysis_sat_precip_amt_mm'].quantile(0.75)-df['reanalysis_sat_precip_amt_mm'].quantile(0.25)
lower=df['reanalysis_sat_precip_amt_mm'].quantile(0.25)-1.5*IQR
upper=df['reanalysis_sat_precip_amt_mm'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -72.025 148.89499999999998

# %%
df=df[df['reanalysis_sat_precip_amt_mm']<=upper]
df.boxplot(column = ['reanalysis_sat_precip_amt_mm'])

# %%
df.boxplot(column = ['reanalysis_specific_humidity_g_per_kg'])

# %%
df.boxplot(column = ['reanalysis_tdtr_k'])

# %%
df.boxplot(column = ['station_avg_temp_c'])

# %%
IQR=df['station_avg_temp_c'].quantile(0.75)-df['station_avg_temp_c'].quantile(0.25)
lower=df['station_avg_temp_c'].quantile(0.25)-1.5*IQR
upper=df['station_avg_temp_c'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# 23.75000000005 30.892857142849998

# %%
df=df[df['station_avg_temp_c']>=lower]
df.boxplot(column = ['station_avg_temp_c'])

# %%
IQR=df['station_avg_temp_c'].quantile(0.75)-df['station_avg_temp_c'].quantile(0.25)
lower=df['station_avg_temp_c'].quantile(0.25)-1.5*IQR
upper=df['station_avg_temp_c'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# 23.785714285799997 30.871428571400003

# %%
df=df[df['station_avg_temp_c']>=lower]
df.boxplot(column = ['station_avg_temp_c'])

# %%
df.boxplot(column = ['station_diur_temp_rng_c'])

# %%
IQR=df['station_diur_temp_rng_c'].quantile(0.75)-df['station_diur_temp_rng_c'].quantile(0.25)
lower=df['station_diur_temp_rng_c'].quantile(0.25)-1.5*IQR
upper=df['station_diur_temp_rng_c'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# 1.8299107142750008 14.512053571434999

# %%
df=df[df['station_diur_temp_rng_c']<=upper]
df.boxplot(column = ['station_diur_temp_rng_c'])

# %%
IQR=df['station_diur_temp_rng_c'].quantile(0.75)-df['station_diur_temp_rng_c'].quantile(0.25)
lower=df['station_diur_temp_rng_c'].quantile(0.25)-1.5*IQR
upper=df['station_diur_temp_rng_c'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# 1.8486607142749998 14.480803571435

# %%
df=df[df['station_diur_temp_rng_c']<=upper]
df.boxplot(column = ['station_diur_temp_rng_c'])

# %%
df.boxplot(column = ['station_max_temp_c'])

# %%
IQR=df['station_max_temp_c'].quantile(0.75)-df['station_max_temp_c'].quantile(0.25)
lower=df['station_max_temp_c'].quantile(0.25)-1.5*IQR
upper=df['station_max_temp_c'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# 27.400000000000006 37.8

# %%
df=df[df['station_max_temp_c']>=lower]
df=df[df['station_max_temp_c']<=upper]
df.boxplot(column = ['station_max_temp_c'])

# %%
IQR=df['station_max_temp_c'].quantile(0.75)-df['station_max_temp_c'].quantile(0.25)
lower=df['station_max_temp_c'].quantile(0.25)-1.5*IQR
upper=df['station_max_temp_c'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# 27.900000000000002 37.5

# %%
df=df[df['station_max_temp_c']>=lower]
df=df[df['station_max_temp_c']<=upper]
df.boxplot(column = ['station_max_temp_c'])

# %%
IQR=df['station_max_temp_c'].quantile(0.75)-df['station_max_temp_c'].quantile(0.25)
lower=df['station_max_temp_c'].quantile(0.25)-1.5*IQR
upper=df['station_max_temp_c'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# 28.4 37.199999999999996

# %%
df=df[df['station_max_temp_c']>=lower]
df=df[df['station_max_temp_c']<=upper]
df.boxplot(column = ['station_max_temp_c'])

# %%
df.boxplot(column = ['station_min_temp_c'])

# %%
IQR=df['station_min_temp_c'].quantile(0.75)-df['station_min_temp_c'].quantile(0.25)
lower=df['station_min_temp_c'].quantile(0.25)-1.5*IQR
upper=df['station_min_temp_c'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# 17.800000000000004 26.6

# %%
df=df[df['station_min_temp_c']>=lower]
df.boxplot(column = ['station_min_temp_c'])

# %%
df.boxplot(column = ['station_precip_mm'])

# %%
IQR=df['station_precip_mm'].quantile(0.75)-df['station_precip_mm'].quantile(0.25)
lower=df['station_precip_mm'].quantile(0.25)-1.5*IQR
upper=df['station_precip_mm'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -51.99999999999999 109.6

# %%
df=df[df['station_precip_mm']<=upper]
df.boxplot(column = ['station_precip_mm'])

# %%
IQR=df['station_precip_mm'].quantile(0.75)-df['station_precip_mm'].quantile(0.25)
lower=df['station_precip_mm'].quantile(0.25)-1.5*IQR
upper=df['station_precip_mm'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -41.474999999999994 90.32499999999999

# %%
df=df[df['station_precip_mm']<=upper]
df.boxplot(column = ['station_precip_mm'])

# %%
IQR=df['station_precip_mm'].quantile(0.75)-df['station_precip_mm'].quantile(0.25)
lower=df['station_precip_mm'].quantile(0.25)-1.5*IQR
upper=df['station_precip_mm'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -37.9 83.7

# %%
df=df[df['station_precip_mm']<=upper]
df.boxplot(column = ['station_precip_mm'])

# %%
IQR=df['station_precip_mm'].quantile(0.75)-df['station_precip_mm'].quantile(0.25)
lower=df['station_precip_mm'].quantile(0.25)-1.5*IQR
upper=df['station_precip_mm'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -36.43750000000001 80.4625

# %%
df=df[df['station_precip_mm']<=upper]
df.boxplot(column = ['station_precip_mm'])

# %%
IQR=df['station_precip_mm'].quantile(0.75)-df['station_precip_mm'].quantile(0.25)
lower=df['station_precip_mm'].quantile(0.25)-1.5*IQR
upper=df['station_precip_mm'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -35.112500000000004 78.1875

# %%
df=df[df['station_precip_mm']<=upper]
df.boxplot(column = ['station_precip_mm'])

# %%
IQR=df['station_precip_mm'].quantile(0.75)-df['station_precip_mm'].quantile(0.25)
lower=df['station_precip_mm'].quantile(0.25)-1.5*IQR
upper=df['station_precip_mm'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -34.65 76.95

# %%
df=df[df['station_precip_mm']<=upper]
df.boxplot(column = ['station_precip_mm'])

# %%
IQR=df['station_precip_mm'].quantile(0.75)-df['station_precip_mm'].quantile(0.25)
lower=df['station_precip_mm'].quantile(0.25)-1.5*IQR
upper=df['station_precip_mm'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -33.9375 75.5625

# %%
df=df[df['station_precip_mm']<=upper]
df.boxplot(column = ['station_precip_mm'])

# %%
IQR=df['station_precip_mm'].quantile(0.75)-df['station_precip_mm'].quantile(0.25)
lower=df['station_precip_mm'].quantile(0.25)-1.5*IQR
upper=df['station_precip_mm'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -33.24999999999999 74.35

# %%
df=df[df['station_precip_mm']<=upper]
df.boxplot(column = ['station_precip_mm'])

# %%
IQR=df['station_precip_mm'].quantile(0.75)-df['station_precip_mm'].quantile(0.25)
lower=df['station_precip_mm'].quantile(0.25)-1.5*IQR
upper=df['station_precip_mm'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -31.700000000000003 71.5

# %%
df=df[df['station_precip_mm']<=upper]
df.boxplot(column = ['station_precip_mm'])

# %%
IQR=df['station_precip_mm'].quantile(0.75)-df['station_precip_mm'].quantile(0.25)
lower=df['station_precip_mm'].quantile(0.25)-1.5*IQR
upper=df['station_precip_mm'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -30.750000000000007 69.65

# %%
df=df[df['station_precip_mm']<=upper]
df.boxplot(column = ['station_precip_mm'])

# %%
IQR=df['station_precip_mm'].quantile(0.75)-df['station_precip_mm'].quantile(0.25)
lower=df['station_precip_mm'].quantile(0.25)-1.5*IQR
upper=df['station_precip_mm'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -30.375 68.625

# %%
df=df[df['station_precip_mm']<=upper]
df.boxplot(column = ['station_precip_mm'])

# %%
df.boxplot(column = ['total_cases'])

# %%
IQR=df['total_cases'].quantile(0.75)-df['total_cases'].quantile(0.25)
lower=df['total_cases'].quantile(0.25)-1.5*IQR
upper=df['total_cases'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -32.5 67.5

# %%
df=df[df['total_cases']<=upper]
df.boxplot(column = ['total_cases'])

# %%
IQR=df['total_cases'].quantile(0.75)-df['total_cases'].quantile(0.25)
lower=df['total_cases'].quantile(0.25)-1.5*IQR
upper=df['total_cases'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -25.0 55.0

# %%
df=df[df['total_cases']<=upper]
df.boxplot(column = ['total_cases'])

# %%
IQR=df['total_cases'].quantile(0.75)-df['total_cases'].quantile(0.25)
lower=df['total_cases'].quantile(0.25)-1.5*IQR
upper=df['total_cases'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -24.5 51.5

# %%
df=df[df['total_cases']<=upper]
df.boxplot(column = ['total_cases'])

# %%
IQR=df['total_cases'].quantile(0.75)-df['total_cases'].quantile(0.25)
lower=df['total_cases'].quantile(0.25)-1.5*IQR
upper=df['total_cases'].quantile(0.75)+1.5*IQR
print(lower,upper)
# Out:
# -23.0 49.0

# %%
df=df[df['total_cases']<=upper]
df.boxplot(column = ['total_cases'])

# %%
IQR=df['total_cases'].quantile(0.75)-df['total_cases'].quantile(0.25)
lower=df['total_cases'].quantile(0.25)-1.5*IQR
upper=df['total_cases'].quantile(0.75)+1.5*IQR

df=df[df['total_cases']<=upper]
df.boxplot(column = ['total_cases'])
